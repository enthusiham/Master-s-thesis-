# %%
import pycaret
from pycaret.regression import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/compat/_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     137 try:
# --> 138     module = importlib.import_module(name)
#     139 except ImportError:
#
# File ~/opt/anaconda3/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# ...

# %%
df_main = pd.read_pickle("df_main.pkl")

# %%
df_main.drop(['_id', 'references'], axis=1, inplace=True)
data = df_main

# %%
data.drop(['authors', 'references_x', 'abstract', 'title'], axis=1, inplace=True)

# %%
conda remove scikit-learn
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/ham/opt/anaconda3
#
#   removed specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-build-3.21.9         |   py39hecd8cb5_0         534 KB
#     jupyter_client-7.2.2       |   py39hecd8cb5_0         192 KB
#     jupyter_server-1.13.5      |     pyhd3eb1b0_0         259 KB
#     jupyterlab-3.3.2           |     pyhd3eb1b0_0         3.6 MB
#     jupyterlab_server-2.10.3   |     pyhd3eb1b0_1          48 KB
#     libarchive-3.5.2           |       ha0e9c3a_0         713 KB
#     libtiff-4.2.0              |       hdb42f99_1         429 KB
#     nbclassic-0.3.5            |     pyhd3eb1b0_0          22 KB
#     nbconvert-6.4.4            |   py39hecd8cb5_0         497 KB
#     notebook-6.4.11            |   py39hecd8cb5_0         4.2 MB
# ...

# %% [markdown]
# import plotly.express as px
# fig = px.scatter(x=data['max_vector_similarity'], y=data['n_citation'], facet_col = data['n_authors'], opacity = 0.25, trendline='ols', trendline_color_override = 'red')
# fig.show()

# %%
conda install -c conda-forge scikit-learn=0.23.2
# Out:
# Error processing line 1 of /Users/ham/opt/anaconda3/lib/python3.9/site-packages/matplotlib-3.5.2-py3.9-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "/Users/ham/opt/anaconda3/lib/python3.9/site.py", line 169, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 562, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/ham/opt/anaconda3
#
#   added / updated specs:
#     - scikit-learn=0.23.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     joblib-1.1.0               |     pyhd8ed1ab_0         210 KB  conda-forge
#     libblas-3.9.0              |15_osx64_openblas          12 KB  conda-forge
# ...

# %%
s = setup(data, target = 'n_citation',  imputation_type='iterative' , transform_target = True, log_experiment = True, fold_shuffle=True,
          numeric_features=['mean_vector_similarity', 'max_vector_similarity', 'mean_ref_year', 'max_ref_year',
                            'mean_ref_n_citation', 'max_ref_n_citation','title_len', 'n_authors', 'n_references'], 
          experiment_name = 'model1')
# Out:
# <style type="text/css">
# #T_e22db_row17_col1, #T_e22db_row54_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e22db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e22db_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e22db_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e22db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e22db_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_e22db_row0_col1" class="data row0 col1" >5206</td>
#     </tr>
#     <tr>
#       <th id="T_e22db_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e22db_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e22db_row1_col1" class="data row1 col1" >n_citation</td>
#     </tr>
#     <tr>
#       <th id="T_e22db_level0_row2" class="row_heading level0 row2" >2</th>
# ...
